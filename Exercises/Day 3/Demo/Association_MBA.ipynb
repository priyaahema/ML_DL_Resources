# %%
# !pip install apyori
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting apyori
#   Downloading apyori-1.1.2.tar.gz (8.6 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: apyori
#   Building wheel for apyori (setup.py) ... done
#   Created wheel for apyori: filename=apyori-1.1.2-py3-none-any.whl size=5956 sha256=521a784df0beed432cefd4d5445821525de8d05a4774a7fb5f3fb809512e039c
#   Stored in directory: /root/.cache/pip/wheels/c4/1a/79/20f55c470a50bb3702a8cb7c94d8ada15573538c7f4baebe2d
# Successfully built apyori
# Installing collected packages: apyori
# Successfully installed apyori-1.1.2

# %%
import pandas as pd
import numpy as np
from apyori import apriori

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv("/content/drive/MyDrive/ML_Data/market_data.csv")
print(df.head())
# Out:
#            shrimp    almonds     avocado    vegetables mix green grapes  \
# 0         burgers  meatballs        eggs               NaN          NaN
# 1         chutney        NaN         NaN               NaN          NaN
# 2          turkey    avocado         NaN               NaN          NaN
# 3   mineral water       milk  energy bar  whole wheat rice    green tea
# 4  low fat yogurt        NaN         NaN               NaN          NaN
#
#   whole weat flour yams cottage cheese energy drink tomato juice  \
# 0              NaN  NaN            NaN          NaN          NaN
# 1              NaN  NaN            NaN          NaN          NaN
# 2              NaN  NaN            NaN          NaN          NaN
# 3              NaN  NaN            NaN          NaN          NaN
# 4              NaN  NaN            NaN          NaN          NaN
#
#   low fat yogurt green tea honey salad mineral water salmon antioxydant juice  \
# 0            NaN       NaN   NaN   NaN           NaN    NaN               NaN
# 1            NaN       NaN   NaN   NaN           NaN    NaN               NaN
# 2            NaN       NaN   NaN   NaN           NaN    NaN               NaN
# 3            NaN       NaN   NaN   NaN           NaN    NaN               NaN
# 4            NaN       NaN   NaN   NaN           NaN    NaN               NaN
#
#   frozen smoothie spinach  olive oil
# 0             NaN     NaN        NaN
# 1             NaN     NaN        NaN
# 2             NaN     NaN        NaN
# 3             NaN     NaN        NaN
# 4             NaN     NaN        NaN

# %%
#converting dataframe into list of lists
l=[]
for i in range(1,10):
    l.append([str(df.values[i,j]) for j in range(0,20)])

# %%
#applying apriori algorithm
association_rules = apriori(l, min_support=0.0045, min_confidence=0.2, min_lift=3, min_length=2)
association_results = list(association_rules)

# %%
for i in range(0, len(association_results)):
    print(association_results[i][0])
# Out:
# frozenset({'avocado', 'turkey'})
# frozenset({'pet food', 'eggs'})
# frozenset({'energy bar', 'green tea'})
# frozenset({'energy bar', 'milk'})
# frozenset({'energy bar', 'mineral water'})
# frozenset({'energy bar', 'whole wheat rice'})
# frozenset({'french fries', 'whole wheat pasta'})
# frozenset({'frozen vegetables', 'green tea'})
# frozenset({'frozen vegetables', 'spaghetti'})
# frozenset({'milk', 'green tea'})
# frozenset({'green tea', 'mineral water'})
# frozenset({'spaghetti', 'green tea'})
# frozenset({'whole wheat rice', 'green tea'})
# frozenset({'light cream', 'shallot'})
# frozenset({'light cream', 'soup'})
# frozenset({'milk', 'mineral water'})
# frozenset({'milk', 'whole wheat rice'})
# frozenset({'whole wheat rice', 'mineral water'})
# frozenset({'shallot', 'soup'})
# frozenset({'avocado', 'turkey', 'nan'})
# frozenset({'pet food', 'eggs', 'nan'})
# frozenset({'energy bar', 'green tea', 'milk'})
# frozenset({'energy bar', 'green tea', 'mineral water'})
# frozenset({'energy bar', 'green tea', 'nan'})
# frozenset({'whole wheat rice', 'energy bar', 'green tea'})
# frozenset({'energy bar', 'milk', 'mineral water'})
# frozenset({'energy bar', 'milk', 'nan'})
# frozenset({'energy bar', 'whole wheat rice', 'milk'})
# frozenset({'energy bar', 'mineral water', 'nan'})
# frozenset({'energy bar', 'whole wheat rice', 'mineral water'})
# frozenset({'energy bar', 'whole wheat rice', 'nan'})
# frozenset({'french fries', 'whole wheat pasta', 'nan'})
# frozenset({'frozen vegetables', 'green tea', 'nan'})
# frozenset({'frozen vegetables', 'spaghetti', 'green tea'})
# frozenset({'frozen vegetables', 'spaghetti', 'nan'})
# frozenset({'milk', 'green tea', 'mineral water'})
# frozenset({'milk', 'green tea', 'nan'})
# frozenset({'whole wheat rice', 'milk', 'green tea'})
# frozenset({'green tea', 'mineral water', 'nan'})
# frozenset({'whole wheat rice', 'green tea', 'mineral water'})
# frozenset({'spaghetti', 'green tea', 'nan'})
# frozenset({'whole wheat rice', 'green tea', 'nan'})
# frozenset({'light cream', 'nan', 'shallot'})
# frozenset({'light cream', 'nan', 'soup'})
# frozenset({'light cream', 'shallot', 'soup'})
# frozenset({'milk', 'mineral water', 'nan'})
# frozenset({'milk', 'whole wheat rice', 'mineral water'})
# frozenset({'milk', 'whole wheat rice', 'nan'})
# frozenset({'whole wheat rice', 'mineral water', 'nan'})
# frozenset({'soup', 'nan', 'shallot'})
# frozenset({'energy bar', 'green tea', 'milk', 'mineral water'})
# frozenset({'energy bar', 'green tea', 'milk', 'nan'})
# frozenset({'whole wheat rice', 'energy bar', 'green tea', 'milk'})
# frozenset({'energy bar', 'green tea', 'mineral water', 'nan'})
# frozenset({'whole wheat rice', 'energy bar', 'green tea', 'mineral water'})
# frozenset({'whole wheat rice', 'energy bar', 'green tea', 'nan'})
# frozenset({'energy bar', 'milk', 'nan', 'mineral water'})
# frozenset({'energy bar', 'whole wheat rice', 'milk', 'mineral water'})
# frozenset({'energy bar', 'whole wheat rice', 'milk', 'nan'})
# frozenset({'energy bar', 'whole wheat rice', 'mineral water', 'nan'})
# frozenset({'frozen vegetables', 'spaghetti', 'green tea', 'nan'})
# frozenset({'milk', 'green tea', 'mineral water', 'nan'})
# frozenset({'whole wheat rice', 'milk', 'green tea', 'mineral water'})
# frozenset({'whole wheat rice', 'milk', 'green tea', 'nan'})
# frozenset({'whole wheat rice', 'green tea', 'mineral water', 'nan'})
# frozenset({'light cream', 'soup', 'nan', 'shallot'})
# frozenset({'milk', 'whole wheat rice', 'mineral water', 'nan'})
# frozenset({'mineral water', 'energy bar', 'green tea', 'milk', 'nan'})
# frozenset({'mineral water', 'energy bar', 'green tea', 'milk', 'whole wheat rice'})
# frozenset({'energy bar', 'green tea', 'milk', 'nan', 'whole wheat rice'})
# frozenset({'mineral water', 'energy bar', 'green tea', 'nan', 'whole wheat rice'})
# frozenset({'mineral water', 'energy bar', 'milk', 'nan', 'whole wheat rice'})
# frozenset({'mineral water', 'milk', 'green tea', 'nan', 'whole wheat rice'})
# frozenset({'mineral water', 'energy bar', 'green tea', 'milk', 'nan', 'whole wheat rice'})

# %%
for item in association_results:
    # first index of the inner list
    # Contains base item and add item
    pair = item[0]
    items = [x for x in pair]
    print("Rule: " + items[0] + " -> " + items[1])
    # second index of the inner list
    print("Support: " + str(item[1]))
    # third index of the list located at 0th position
    # of the third index of the inner list
    print("Confidence: " + str(item[2][0][2]))
    print("Lift: " + str(item[2][0][3]))
    print("-----------------------------------------------------")
# Out:
# Rule: avocado -> turkey
# Support: 0.1111111111111111
# Confidence: 1.0
# Lift: 9.0
# -----------------------------------------------------
# Rule: pet food -> eggs
# Support: 0.1111111111111111
# Confidence: 1.0
# Lift: 9.0
# -----------------------------------------------------
# Rule: energy bar -> green tea
# Support: 0.1111111111111111
# Confidence: 1.0
# Lift: 4.5
# -----------------------------------------------------
# Rule: energy bar -> milk
# Support: 0.1111111111111111
# Confidence: 1.0
# Lift: 9.0
# -----------------------------------------------------
# Rule: energy bar -> mineral water
# Support: 0.1111111111111111
# Confidence: 1.0
# Lift: 9.0
# -----------------------------------------------------
# Rule: energy bar -> whole wheat rice
# Support: 0.1111111111111111
# Confidence: 1.0
# Lift: 9.0
# -----------------------------------------------------
# Rule: french fries -> whole wheat pasta
# Support: 0.1111111111111111
# Confidence: 0.5
# Lift: 4.5
# -----------------------------------------------------
# Rule: frozen vegetables -> green tea
# Support: 0.1111111111111111
# Confidence: 1.0
# Lift: 4.5
# -----------------------------------------------------
# Rule: frozen vegetables -> spaghetti
# Support: 0.1111111111111111
# Confidence: 1.0
# Lift: 9.0
# -----------------------------------------------------
# Rule: milk -> green tea
# Support: 0.1111111111111111
# Confidence: 0.5
# Lift: 4.5
# -----------------------------------------------------
# Rule: green tea -> mineral water
# Support: 0.1111111111111111
# Confidence: 0.5
# Lift: 4.5
# -----------------------------------------------------
# Rule: spaghetti -> green tea
# Support: 0.1111111111111111
# Confidence: 0.5
# Lift: 4.5
# -----------------------------------------------------
# Rule: whole wheat rice -> green tea
# Support: 0.1111111111111111
# Confidence: 0.5
# Lift: 4.5
# -----------------------------------------------------
# Rule: light cream -> shallot
# Support: 0.1111111111111111
# Confidence: 1.0
# Lift: 9.0
# -----------------------------------------------------
# Rule: light cream -> soup
# Support: 0.1111111111111111
# Confidence: 1.0
# Lift: 9.0
# -----------------------------------------------------
# Rule: milk -> mineral water
# Support: 0.1111111111111111
# Confidence: 1.0
# Lift: 9.0
# -----------------------------------------------------
# Rule: milk -> whole wheat rice
# Support: 0.1111111111111111
# Confidence: 1.0
# Lift: 9.0
# -----------------------------------------------------
# Rule: whole wheat rice -> mineral water
# Support: 0.1111111111111111
# Confidence: 1.0
# Lift: 9.0
# -----------------------------------------------------
# Rule: shallot -> soup
# Support: 0.1111111111111111
# Confidence: 1.0
# Lift: 9.0
# -----------------------------------------------------
# Rule: avocado -> turkey
# Support: 0.1111111111111111
# Confidence: 1.0
# Lift: 9.0
# -----------------------------------------------------
# Rule: pet food -> eggs
# Support: 0.1111111111111111
# Confidence: 1.0
# Lift: 9.0
# -----------------------------------------------------
# Rule: energy bar -> green tea
# Support: 0.1111111111111111
# Confidence: 1.0
# Lift: 9.0
# -----------------------------------------------------
# Rule: energy bar -> green tea
# Support: 0.1111111111111111
# Confidence: 1.0
# Lift: 9.0
# -----------------------------------------------------
# Rule: energy bar -> green tea
# Support: 0.1111111111111111
# Confidence: 1.0
# Lift: 4.5
# -----------------------------------------------------
# Rule: whole wheat rice -> energy bar
# Support: 0.1111111111111111
# Confidence: 1.0
# Lift: 9.0
# -----------------------------------------------------
# Rule: energy bar -> milk
# Support: 0.1111111111111111
# Confidence: 1.0
# Lift: 9.0
# -----------------------------------------------------
# Rule: energy bar -> milk
# Support: 0.1111111111111111
# Confidence: 1.0
# Lift: 9.0
# -----------------------------------------------------
# Rule: energy bar -> whole wheat rice
# Support: 0.1111111111111111
# Confidence: 1.0
# Lift: 9.0
# -----------------------------------------------------
# Rule: energy bar -> mineral water
# Support: 0.1111111111111111
# Confidence: 1.0
# Lift: 9.0
# -----------------------------------------------------
# Rule: energy bar -> whole wheat rice
# Support: 0.1111111111111111
# Confidence: 1.0
# Lift: 9.0
# -----------------------------------------------------
# Rule: energy bar -> whole wheat rice
# Support: 0.1111111111111111
# Confidence: 1.0
# Lift: 9.0
# -----------------------------------------------------
# Rule: french fries -> whole wheat pasta
# Support: 0.1111111111111111
# Confidence: 0.5
# Lift: 4.5
# -----------------------------------------------------
# Rule: frozen vegetables -> green tea
# Support: 0.1111111111111111
# Confidence: 1.0
# Lift: 4.5
# -----------------------------------------------------
# Rule: frozen vegetables -> spaghetti
# Support: 0.1111111111111111
# Confidence: 1.0
# Lift: 9.0
# -----------------------------------------------------
# Rule: frozen vegetables -> spaghetti
# Support: 0.1111111111111111
# Confidence: 1.0
# Lift: 9.0
# -----------------------------------------------------
# Rule: milk -> green tea
# Support: 0.1111111111111111
# Confidence: 0.5
# Lift: 4.5
# -----------------------------------------------------
# Rule: milk -> green tea
# Support: 0.1111111111111111
# Confidence: 0.5
# Lift: 4.5
# -----------------------------------------------------
# Rule: whole wheat rice -> milk
# Support: 0.1111111111111111
# Confidence: 0.5
# Lift: 4.5
# -----------------------------------------------------
# Rule: green tea -> mineral water
# Support: 0.1111111111111111
# Confidence: 0.5
# Lift: 4.5
# -----------------------------------------------------
# Rule: whole wheat rice -> green tea
# Support: 0.1111111111111111
# Confidence: 0.5
# Lift: 4.5
# -----------------------------------------------------
# Rule: spaghetti -> green tea
# Support: 0.1111111111111111
# Confidence: 0.5
# Lift: 4.5
# -----------------------------------------------------
# Rule: whole wheat rice -> green tea
# Support: 0.1111111111111111
# Confidence: 0.5
# Lift: 4.5
# -----------------------------------------------------
# Rule: light cream -> nan
# Support: 0.1111111111111111
# Confidence: 1.0
# Lift: 9.0
# -----------------------------------------------------
# Rule: light cream -> nan
# Support: 0.1111111111111111
# Confidence: 1.0
# Lift: 9.0
# -----------------------------------------------------
# Rule: light cream -> shallot
# Support: 0.1111111111111111
# Confidence: 1.0
# Lift: 9.0
# -----------------------------------------------------
# Rule: milk -> mineral water
# Support: 0.1111111111111111
# Confidence: 1.0
# Lift: 9.0
# -----------------------------------------------------
# Rule: milk -> whole wheat rice
# Support: 0.1111111111111111
# Confidence: 1.0
# Lift: 9.0
# -----------------------------------------------------
# Rule: milk -> whole wheat rice
# Support: 0.1111111111111111
# Confidence: 1.0
# Lift: 9.0
# -----------------------------------------------------
# Rule: whole wheat rice -> mineral water
# Support: 0.1111111111111111
# Confidence: 1.0
# Lift: 9.0
# -----------------------------------------------------
# Rule: soup -> nan
# Support: 0.1111111111111111
# Confidence: 1.0
# Lift: 9.0
# -----------------------------------------------------
# Rule: energy bar -> green tea
# Support: 0.1111111111111111
# Confidence: 1.0
# Lift: 9.0
# -----------------------------------------------------
# Rule: energy bar -> green tea
# Support: 0.1111111111111111
# Confidence: 1.0
# Lift: 9.0
# -----------------------------------------------------
# Rule: whole wheat rice -> energy bar
# Support: 0.1111111111111111
# Confidence: 1.0
# Lift: 9.0
# -----------------------------------------------------
# Rule: energy bar -> green tea
# Support: 0.1111111111111111
# Confidence: 1.0
# Lift: 9.0
# -----------------------------------------------------
# Rule: whole wheat rice -> energy bar
# Support: 0.1111111111111111
# Confidence: 1.0
# Lift: 9.0
# -----------------------------------------------------
# Rule: whole wheat rice -> energy bar
# Support: 0.1111111111111111
# Confidence: 1.0
# Lift: 9.0
# -----------------------------------------------------
# Rule: energy bar -> milk
# Support: 0.1111111111111111
# Confidence: 1.0
# Lift: 9.0
# -----------------------------------------------------
# Rule: energy bar -> whole wheat rice
# Support: 0.1111111111111111
# Confidence: 1.0
# Lift: 9.0
# -----------------------------------------------------
# Rule: energy bar -> whole wheat rice
# Support: 0.1111111111111111
# Confidence: 1.0
# Lift: 9.0
# -----------------------------------------------------
# Rule: energy bar -> whole wheat rice
# Support: 0.1111111111111111
# Confidence: 1.0
# Lift: 9.0
# -----------------------------------------------------
# Rule: frozen vegetables -> spaghetti
# Support: 0.1111111111111111
# Confidence: 1.0
# Lift: 9.0
# -----------------------------------------------------
# Rule: milk -> green tea
# Support: 0.1111111111111111
# Confidence: 0.5
# Lift: 4.5
# -----------------------------------------------------
# Rule: whole wheat rice -> milk
# Support: 0.1111111111111111
# Confidence: 0.5
# Lift: 4.5
# -----------------------------------------------------
# Rule: whole wheat rice -> milk
# Support: 0.1111111111111111
# Confidence: 0.5
# Lift: 4.5
# -----------------------------------------------------
# Rule: whole wheat rice -> green tea
# Support: 0.1111111111111111
# Confidence: 0.5
# Lift: 4.5
# -----------------------------------------------------
# Rule: light cream -> soup
# Support: 0.1111111111111111
# Confidence: 1.0
# Lift: 9.0
# -----------------------------------------------------
# Rule: milk -> whole wheat rice
# Support: 0.1111111111111111
# Confidence: 1.0
# Lift: 9.0
# -----------------------------------------------------
# Rule: mineral water -> energy bar
# Support: 0.1111111111111111
# Confidence: 1.0
# Lift: 9.0
# -----------------------------------------------------
# Rule: mineral water -> energy bar
# Support: 0.1111111111111111
# Confidence: 1.0
# Lift: 9.0
# -----------------------------------------------------
# Rule: energy bar -> green tea
# Support: 0.1111111111111111
# Confidence: 1.0
# Lift: 9.0
# -----------------------------------------------------
# Rule: mineral water -> energy bar
# Support: 0.1111111111111111
# Confidence: 1.0
# Lift: 9.0
# -----------------------------------------------------
# Rule: mineral water -> energy bar
# Support: 0.1111111111111111
# Confidence: 1.0
# Lift: 9.0
# -----------------------------------------------------
# Rule: mineral water -> milk
# Support: 0.1111111111111111
# Confidence: 0.5
# Lift: 4.5
# -----------------------------------------------------
# Rule: mineral water -> energy bar
# Support: 0.1111111111111111
# Confidence: 1.0
# Lift: 9.0
# -----------------------------------------------------
